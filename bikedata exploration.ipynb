# %%
import pandas as pd
bike = pd.read_csv("BikeData.csv")
bike.head(15)
# Out:
#     Rented Bike Count  Temperature  Humidity  Wind speed  Visibility  \
# 0                 254         -5.2        37         2.2        2000
# 1                 204         -5.5        38         0.8        2000
# 2                 173         -6.0        39         1.0        2000
# 3                 107         -6.2        40         0.9        2000
# 4                  78         -6.0        36         2.3        2000
# 5                 100         -6.4        37         1.5        2000
# 6                 181         -6.6        35         1.3        2000
# 7                 460         -7.4        38         0.9        2000
# 8                 930         -7.6        37         1.1        2000
# 9                 490         -6.5        27         0.5        1928
# 10                339         -3.5        24         1.2        1996
# 11                360         -0.5        21         1.3        1936
# 12                449          1.7        23         1.4        2000
# ...

# %%
bike.describe()
# Out:
#        Rented Bike Count  Temperature     Humidity   Wind speed   Visibility  \
# count        8465.000000  8465.000000  8465.000000  8465.000000  8465.000000
# mean          729.156999    12.771057    58.147194     1.725883  1433.873479
# std           642.351166    12.104375    20.484839     1.034281   609.051229
# min             2.000000   -17.800000     0.000000     0.000000    27.000000
# 25%           214.000000     3.000000    42.000000     0.900000   935.000000
# 50%           542.000000    13.500000    57.000000     1.500000  1690.000000
# 75%          1084.000000    22.700000    74.000000     2.300000  2000.000000
# max          3556.000000    39.400000    98.000000     7.400000  2000.000000
#
#        Dew point temperature  Solar Radiation    Rainfall     Snowfall
# count            8465.000000      8465.000000  8465.00000  8465.000000
# mean                3.944997         0.567868     0.14912     0.077685
# ...

# %%
bike["Rented Bike Count"].plot()
# Out:
# <Axes: >

# %%
bike["Rented Bike Count"].iloc[0:100].plot()
# Out:
# <Axes: >

# %%
bike[bike["Seasons"]== "Summer"]
# Out:
#       Rented Bike Count  Temperature  Humidity  Wind speed  Visibility  \
# 4320                963         20.1        63         1.1        1698
# 4321                776         19.5        65         0.4        1662
# 4322                554         19.0        72         1.4        1258
# 4323                366         18.6        72         1.4        1340
# 4324                265         18.1        76         1.8         561
# ...                 ...          ...       ...         ...         ...
# 6523               2372         26.5        69         2.3        2000
# 6524               1995         25.4        74         1.6        2000
# 6525               1931         24.5        78         1.2        2000
# 6526               1789         24.1        80         0.9        1852
# 6527               1329         23.8        81         0.6        1893
#
#       Dew point temperature  Solar Radiation  Rainfall  Snowfall Seasons  \
# ...

# %%
bike.groupby("Seasons")["Rented Bike Count"]
# Out:
# Seasons
# Autumn    1790002
# Spring    1611909
# Summer    2283234
# Winter     487169
# Name: Rented Bike Count, dtype: int64

# %%
bike.groupby("Seasons").agg({"Rented Bike Count":"sum","Rainfall":"max","Temperature":"min"})
# Out:
#          Rented Bike Count  Rainfall  Temperature
# Seasons
# Autumn             1790002      18.0         -3.0
# Spring             1611909      35.0         -6.6
# Summer             2283234      29.5         16.3
# Winter              487169       9.5        -17.8
